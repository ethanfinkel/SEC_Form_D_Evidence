# %%
#Imports
import pandas as pd
import duckdb as db
import numpy as np
from dateutil import parser

# %%
"""
Specify path where form D files are stored. 
These can be downloaded from https://www.sec.gov/data-research/sec-markets-data/form-d-data-sets.
This notebook is structured to have each folder from the SEC data set stored in the folder Form_D_data. 
"""
path = "../Form_D_data"

# %%
#Load the offerings TSVs from every folder in the Form D directory
offerings = db.read_csv(f"{path}/*/OFFERING.tsv", dtype={'TOTALOFFERINGAMOUNT': 'VARCHAR','TOTALREMAINING': 'VARCHAR'}).df()
offerings
# Out:
#              ACCESSIONNUMBER       INDUSTRYGROUPTYPE     INVESTMENTFUNDTYPE  \
# 0       0001477399-09-000001      Investment Banking                   None
# 1       0001192482-09-000126  Pooled Investment Fund    Private Equity Fund
# 2       0001446406-08-000001             Restaurants                   None
# 3       0001446409-08-000001             Restaurants                   None
# 4       0001446405-08-000001             Restaurants                   None
# ...                      ...                     ...                    ...
# 647283  0001062993-23-023297                   Other                   None
# 647284  0002005968-23-000002  Pooled Investment Fund    Private Equity Fund
# 647285  0001750134-23-000001  Pooled Investment Fund             Hedge Fund
# 647286  0002005978-23-000002  Pooled Investment Fund    Private Equity Fund
# 647287  0002006335-23-000001  Pooled Investment Fund  Other Investment Fund
#
#        IS40ACT              REVENUERANGE AGGREGATENETASSETVALUERANGE  \
# 0         None  $5,000,001 - $25,000,000                        None
# 1        false       Decline to Disclose                        None
# 2         None       Decline to Disclose                        None
# 3         None               No Revenues                        None
# 4         None  $5,000,001 - $25,000,000                        None
# ...        ...                       ...                         ...
# 647283    None            Not Applicable                        None
# 647284   false       Decline to Disclose                        None
# 647285   false                      None         Decline to Disclose
# 647286   false       Decline to Disclose                        None
# 647287   false                      None         Decline to Disclose
#
#        FEDERALEXEMPTIONS_ITEMS_LIST  ISAMENDMENT PREVIOUSACCESSIONNUMBER  \
# 0                                06        False                    None
# 1                      06, 3C, 3C.7        False                    None
# 2                                06        False                    None
# 3                                06        False                    None
# 4                                06        False                    None
# ...                             ...          ...                     ...
# 647283                          06b        False                    None
# 647284                06b, 3C, 3C.7        False                    None
# 647285                          06c         True    0001750134-22-000001
# 647286                06b, 3C, 3C.7        False                    None
# 647287                06b, 3C, 3C.9        False                    None
#
#          SALE_DATE  ... TOTALNUMBERALREADYINVESTED  SALESCOMM_DOLLARAMOUNT  \
# 0             None  ...                          0                       0
# 1       2008-05-15  ...                          6                       0
# 2       2007-09-21  ...                          5                       0
# 3       2008-09-30  ...                          2                       0
# 4       2004-01-26  ...                         41                       0
# ...            ...  ...                        ...                     ...
# 647283  2023-12-22  ...                          1                       0
# 647284        None  ...                          0                       0
# 647285  2018-08-03  ...                        578                       0
# 647286        None  ...                          0                       0
# 647287        None  ...                          0                       0
#
#        SALESCOMM_ISESTIMATE FINDERSFEE_DOLLARAMOUNT FINDERSFEE_ISESTIMATE  \
# 0                      None                       0                  None
# 1                      None                       0                  None
# 2                      None                       0                  None
# 3                      None                       0                  None
# 4                      None                       0                  None
# ...                     ...                     ...                   ...
# 647283                 None                       0                  None
# 647284                 None                       0                  None
# 647285                 None                       0                  None
# 647286                 None                       0                  None
# 647287                 None                       0                  None
#
#                              FINDERFEECLARIFICATIONOFRESP  \
# 0                                                    None
# 1       Financial advisers of individual investors may...
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 647283                                               None
# 647284                                               None
# 647285                                               None
# 647286                                               None
# 647287                                               None
#
#        GROSSPROCEEDSUSED_DOLLARAMOUNT GROSSPROCEEDSUSED_ISESTIMATE  \
# 0                                   0                         None
# 1                                   0                         None
# 2                                   0                         None
# 3                                   0                         None
# 4                                   0                         None
# ...                               ...                          ...
# 647283                              0                         None
# 647284                              0                         None
# 647285                              0                         None
# 647286                              0                         None
# 647287                              0                         None
#
#                              GROSSPROCEEDSUSED_CLAROFRESP  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 647283                                               None
# 647284                                               None
# 647285                                               None
# 647286                                               None
# 647287  The Investment Manager receives a management f...
#
#        AUTHORIZEDREPRESENTATIVE
# 0                         False
# 1                         False
# 2                          True
# 3                          True
# 4                          True
# ...                         ...
# 647283                    False
# 647284                    False
# 647285                    False
# 647286                    False
# 647287                    False
#
# [647288 rows x 41 columns]

# %%
#Load the issuers TSVs from every folder in the Form D directory
issuers = db.read_csv(f"{path}/*/ISSUERS.tsv", dtype={'ISSUERPHONENUMBER':'VARCHAR','ZIPCODE':'VARCHAR'}).df()
issuers
# Out:
#              ACCESSIONNUMBER IS_PRIMARYISSUER_FLAG  ISSUER_SEQ_KEY  \
# 0       0001477399-09-000001                   YES             101
# 1       0001192482-09-000126                   YES             101
# 2       0001446406-08-000001                   YES             101
# 3       0001446409-08-000001                   YES             101
# 4       0001446405-08-000001                   YES             101
# ...                      ...                   ...             ...
# 657232  0002014428-24-000001                   YES             101
# 657233  0001659341-24-000006                   YES             101
# 657234  0002017325-24-000001                   YES             101
# 657235  0001659341-24-000004                   YES             101
# 657236  0001915864-24-000001                   YES             101
#
#                CIK                                         ENTITYNAME  \
# 0       0001477399                     CSA Biotechnology Fund II, LLC
# 1       0001461727  Oppenheimer Global Resource Private Equity Off...
# 2       0001446406                         Dolce Group Huntsville LLC
# 3       0001446409                     Dolce Group Hollywood Vine LLC
# 4       0001446405                                   Geisha House LLC
# ...            ...                                                ...
# 657232  0002014428                       Lower Tier WA13 Holdings, LP
# 657233  0001869503                          NEPC Global Equity Series
# 657234  0002017325                                Anthems Media, Inc.
# 657235  0001649416  Mercer Diocese of Brooklyn Risk Reduction Stra...
# 657236  0001915864                                    SYMPHONY42 Corp
#
#                                      STREET1                     STREET2  \
# 0                        Two Metroplex Drive                   Suite 111
# 1       C/O OPPENHEIMER ASSET MANAGEMENT LLC            125 BROAD STREET
# 2                   365 THE BRIDGE STREET NW                   SUITE 125
# 3                           1708 VINE STREET                        None
# 4                   6633 HOLLYWOOD BOULEVARD                        None
# ...                                      ...                         ...
# 657232            750 PARK OF COMMERCE DRIVE                   SUITE 210
# 657233              c/o Global Trust Company  12 Gill Street, Suite 2600
# 657234            2232 NORTH POINT STREET #3                        None
# 657235              c/o Global Trust Company  12 Gill Street, Suite 2600
# 657236               11400 BARLEY FIELDS WAY                        None
#
#                   CITY STATEORCOUNTRY STATEORCOUNTRYDESCRIPTION  ...  \
# 0           BIRMINGHAM             AL                      None  ...
# 1             NEW YORK             NY                      None  ...
# 2           HUNTSVILLE             AL                      None  ...
# 3            HOLLYWOOD             CA                      None  ...
# 4            HOLLYWOOD             CA                      None  ...
# ...                ...            ...                       ...  ...
# 657232      BOCA RATON             FL                   FLORIDA  ...
# 657233          Woburn             MA             MASSACHUSETTS  ...
# 657234   SAN FRANCISCO             CA                CALIFORNIA  ...
# 657235          WOBURN             MA             MASSACHUSETTS  ...
# 657236  MARRIOTTSVILLE             MD                  MARYLAND  ...
#
#        ISSUER_PREVIOUSNAME_1 ISSUER_PREVIOUSNAME_2 ISSUER_PREVIOUSNAME_3  \
# 0                       None                  None                  None
# 1                       None                  None                  None
# 2                       None                  None                  None
# 3                       None                  None                  None
# 4                       None                  None                  None
# ...                      ...                   ...                   ...
# 657232                  None                  None                  None
# 657233                  None                  None                  None
# 657234                  None                  None                  None
# 657235                  None                  None                  None
# 657236                  None                  None                  None
#
#        EDGAR_PREVIOUSNAME_1 EDGAR_PREVIOUSNAME_2 EDGAR_PREVIOUSNAME_3  \
# 0                      None                 None                 None
# 1                      None                 None                 None
# 2                      None                 None                 None
# 3                      None                 None                 None
# 4                      None                 None                 None
# ...                     ...                  ...                  ...
# 657232                 None                 None                 None
# 657233                 None                 None                 None
# 657234                 None                 None                 None
# 657235                 None                 None                 None
# 657236                 None                 None                 None
#
#                        ENTITYTYPE  \
# 0       Limited Liability Company
# 1             Limited Partnership
# 2       Limited Liability Company
# 3       Limited Liability Company
# 4       Limited Liability Company
# ...                           ...
# 657232        Limited Partnership
# 657233                      Other
# 657234                Corporation
# 657235                      Other
# 657236                Corporation
#
#                                       ENTITYTYPEOTHERDESC  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 657232                                               None
# 657233  The issuer is a protected series of NEPC Inves...
# 657234                                               None
# 657235  Mercer Diocese of Brooklyn Risk Reduction Stra...
# 657236                                               None
#
#        YEAROFINC_TIMESPAN_CHOICE YEAROFINC_VALUE_ENTERED
# 0                withinFiveYears                  2007.0
# 1                withinFiveYears                  2007.0
# 2                withinFiveYears                  2006.0
# 3                withinFiveYears                  2008.0
# 4                withinFiveYears                  2004.0
# ...                          ...                     ...
# 657232           withinFiveYears                  2024.0
# 657233           withinFiveYears                  2021.0
# 657234             overFiveYears                     NaN
# 657235             overFiveYears                     NaN
# 657236           withinFiveYears                  2021.0
#
# [657237 rows x 23 columns]

# %%
#Load the form_d_submissions TSVs from every folder in the Form D directory
form_d_submission = db.read_csv(f"{path}/*/FORMDSUBMISSION.tsv", dtype={'FILING_DATE':'VARCHAR'}).df()
form_d_submission
# Out:
#              ACCESSIONNUMBER                   FILE_NUM          FILING_DATE  \
# 0       0001477399-09-000001  021-136347                 2008-01-02 06:01:00
# 1       0001192482-09-000126  021-131415                 2008-05-30 06:01:00
# 2       0001446406-08-000001  021-123021                 2008-09-30 17:24:23
# 3       0001446409-08-000001  021-123020                 2008-09-30 16:51:44
# 4       0001446405-08-000001  021-123019                 2008-09-30 16:33:23
# ...                      ...                        ...                  ...
# 647283  0002005968-23-000002  021-501236                         02-JAN-2024
# 647284  0001062993-23-023297  021-501235                         02-JAN-2024
# 647285  0002003898-23-000003  021-501229                         02-JAN-2024
# 647286  0002003898-23-000001  021-501223                         02-JAN-2024
# 647287  0002006335-23-000001  021-501224                         02-JAN-2024
#
#        SIC_CODE SCHEMAVERSION SUBMISSIONTYPE TESTORLIVE OVER100PERSONSFLAG  \
# 0          None         X0603              D       LIVE               None
# 1          None         X0301              D       LIVE               None
# 2          None         X0101              D       LIVE               None
# 3          None         X0101              D       LIVE               None
# 4          None         X0101              D       LIVE               None
# ...         ...           ...            ...        ...                ...
# 647283     None         X0708              D       LIVE               None
# 647284     None         X0708              D       LIVE               None
# 647285     None         X0708              D       LIVE               None
# 647286     None         X0708              D       LIVE               None
# 647287     None         X0708              D       LIVE               None
#
#        OVER100ISSUERFLAG
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# ...                  ...
# 647283              None
# 647284              None
# 647285              None
# 647286              None
# 647287              None
#
# [647288 rows x 9 columns]

# %%
#This query joins the three data frames together 

joins = """
select * from offerings as o 
left join issuers as i on i.ACCESSIONNUMBER = o.ACCESSIONNUMBER
left join form_d_submission as fds on fds.ACCESSIONNUMBER = o.ACCESSIONNUMBER
"""

where = """
where INVESTMENTFUNDTYPE = 'Venture Capital Fund'
"""

query = joins + where

df = db.query(f'{query}').df()
df
# Out:
#             ACCESSIONNUMBER       INDUSTRYGROUPTYPE    INVESTMENTFUNDTYPE  \
# 0      0001984536-23-000001  Pooled Investment Fund  Venture Capital Fund
# 1      0001984537-23-000001  Pooled Investment Fund  Venture Capital Fund
# 2      0001984773-23-000001  Pooled Investment Fund  Venture Capital Fund
# 3      0001984539-23-000001  Pooled Investment Fund  Venture Capital Fund
# 4      0001983466-23-000001  Pooled Investment Fund  Venture Capital Fund
# ...                     ...                     ...                   ...
# 47931  0001994032-23-000002  Pooled Investment Fund  Venture Capital Fund
# 47932  0001972237-23-000003  Pooled Investment Fund  Venture Capital Fund
# 47933  0001986286-23-000002  Pooled Investment Fund  Venture Capital Fund
# 47934  0001988652-23-000002  Pooled Investment Fund  Venture Capital Fund
# 47935  0001988021-23-000001  Pooled Investment Fund  Venture Capital Fund
#
#       IS40ACT         REVENUERANGE AGGREGATENETASSETVALUERANGE  \
# 0       false  Decline to Disclose                        None
# 1       false  Decline to Disclose                        None
# 2       false  Decline to Disclose                        None
# 3       false  Decline to Disclose                        None
# 4       false  Decline to Disclose                        None
# ...       ...                  ...                         ...
# 47931   false  Decline to Disclose                        None
# 47932   false  Decline to Disclose                        None
# 47933   false  Decline to Disclose                        None
# 47934   false  Decline to Disclose                        None
# 47935   false  Decline to Disclose                        None
#
#       FEDERALEXEMPTIONS_ITEMS_LIST  ISAMENDMENT PREVIOUSACCESSIONNUMBER  \
# 0                    06b, 3C, 3C.1        False                    None
# 1                    06b, 3C, 3C.1        False                    None
# 2                    06b, 3C, 3C.1        False                    None
# 3                    06b, 3C, 3C.1        False                    None
# 4              06b, 3C, 3C.1, 3C.7        False                    None
# ...                            ...          ...                     ...
# 47931                06b, 3C, 3C.1        False                    None
# 47932                          06c         True    0001972237-23-000002
# 47933                06c, 3C, 3C.1        False                    None
# 47934                06b, 3C, 3C.1        False                    None
# 47935                06b, 3C, 3C.1        False                    None
#
#         SALE_DATE  ... YEAROFINC_VALUE_ENTERED     ACCESSIONNUMBER_2  \
# 0      2023-06-30  ...                  2023.0  0001984536-23-000001
# 1      2023-06-30  ...                  2023.0  0001984537-23-000001
# 2      2023-06-30  ...                  2023.0  0001984773-23-000001
# 3      2023-06-30  ...                  2023.0  0001984539-23-000001
# 4            None  ...                  2023.0  0001983466-23-000001
# ...           ...  ...                     ...                   ...
# 47931  2023-09-19  ...                  2023.0  0001994032-23-000002
# 47932  2023-04-07  ...                  2023.0  0001972237-23-000003
# 47933  2023-08-09  ...                  2023.0  0001986286-23-000002
# 47934  2023-08-01  ...                  2023.0  0001988652-23-000002
# 47935  2023-07-25  ...                  2023.0  0001988021-23-000001
#
#                         FILE_NUM  FILING_DATE SIC_CODE SCHEMAVERSION  \
# 0      021-486764                 13-JUL-2023     None         X0708
# 1      021-486762                 13-JUL-2023     None         X0708
# 2      021-486755                 13-JUL-2023     None         X0708
# 3      021-486754                 13-JUL-2023     None         X0708
# 4      021-486751                 13-JUL-2023     None         X0708
# ...                          ...          ...      ...           ...
# 47931  021-492526                 20-SEP-2023     None         X0708
# 47932  021-479110                 17-AUG-2023     None         X0708
# 47933  021-489519                 11-AUG-2023     None         X0708
# 47934  021-488753                 04-AUG-2023     None         X0708
# 47935  021-488454                 01-AUG-2023     None         X0708
#
#       SUBMISSIONTYPE TESTORLIVE OVER100PERSONSFLAG OVER100ISSUERFLAG
# 0                  D       LIVE               None              None
# 1                  D       LIVE               None              None
# 2                  D       LIVE               None              None
# 3                  D       LIVE               None              None
# 4                  D       LIVE               None              None
# ...              ...        ...                ...               ...
# 47931              D       LIVE               None              None
# 47932            D/A       LIVE               None              None
# 47933              D       LIVE               None              None
# 47934              D       LIVE               None              None
# 47935              D       LIVE               None              None
#
# [47936 rows x 73 columns]

# %%
def normalize_date(date_str):
    if pd.isna(date_str):
        return np.nan
    try:
        # Try to parse the date string
        parsed_date = parser.parse(date_str)
        # Return the date in a standard format
        return parsed_date.strftime('%Y-%m-%d')
    except:
        # If parsing fails, return NaN or the original string
        return np.nan  # or return date_str if you prefer

# Apply the function to your DataFrame column
df['normalized_date'] = df['FILING_DATE'].apply(normalize_date)

# %%
#Filter out prior filings for the same fund
previous_accession_numbers = set(df['PREVIOUSACCESSIONNUMBER'].dropna())
vc = df[~df['ACCESSIONNUMBER'].isin(previous_accession_numbers)]

# %%
# Create a new DuckDB database file
vc_database = db.connect('vc_database.duckdb')

# Execute the join query and write the results directly to the new database
vc_database.execute(f"""
CREATE TABLE vc_data AS
select * from vc
""")

vc_database.execute(f'select * from vc').df()
# Out:
#             ACCESSIONNUMBER       INDUSTRYGROUPTYPE    INVESTMENTFUNDTYPE  \
# 0      0001984536-23-000001  Pooled Investment Fund  Venture Capital Fund
# 1      0001984537-23-000001  Pooled Investment Fund  Venture Capital Fund
# 2      0001984773-23-000001  Pooled Investment Fund  Venture Capital Fund
# 3      0001984539-23-000001  Pooled Investment Fund  Venture Capital Fund
# 4      0001983466-23-000001  Pooled Investment Fund  Venture Capital Fund
# ...                     ...                     ...                   ...
# 40934  0001994032-23-000002  Pooled Investment Fund  Venture Capital Fund
# 40935  0001972237-23-000003  Pooled Investment Fund  Venture Capital Fund
# 40936  0001986286-23-000002  Pooled Investment Fund  Venture Capital Fund
# 40937  0001988652-23-000002  Pooled Investment Fund  Venture Capital Fund
# 40938  0001988021-23-000001  Pooled Investment Fund  Venture Capital Fund
#
#       IS40ACT         REVENUERANGE  AGGREGATENETASSETVALUERANGE  \
# 0       false  Decline to Disclose                          NaN
# 1       false  Decline to Disclose                          NaN
# 2       false  Decline to Disclose                          NaN
# 3       false  Decline to Disclose                          NaN
# 4       false  Decline to Disclose                          NaN
# ...       ...                  ...                          ...
# 40934   false  Decline to Disclose                          NaN
# 40935   false  Decline to Disclose                          NaN
# 40936   false  Decline to Disclose                          NaN
# 40937   false  Decline to Disclose                          NaN
# 40938   false  Decline to Disclose                          NaN
#
#       FEDERALEXEMPTIONS_ITEMS_LIST  ISAMENDMENT PREVIOUSACCESSIONNUMBER  \
# 0                    06b, 3C, 3C.1        False                    None
# 1                    06b, 3C, 3C.1        False                    None
# 2                    06b, 3C, 3C.1        False                    None
# 3                    06b, 3C, 3C.1        False                    None
# 4              06b, 3C, 3C.1, 3C.7        False                    None
# ...                            ...          ...                     ...
# 40934                06b, 3C, 3C.1        False                    None
# 40935                          06c         True    0001972237-23-000002
# 40936                06c, 3C, 3C.1        False                    None
# 40937                06b, 3C, 3C.1        False                    None
# 40938                06b, 3C, 3C.1        False                    None
#
#         SALE_DATE  ...     ACCESSIONNUMBER_2                   FILE_NUM  \
# 0      2023-06-30  ...  0001984536-23-000001  021-486764
# 1      2023-06-30  ...  0001984537-23-000001  021-486762
# 2      2023-06-30  ...  0001984773-23-000001  021-486755
# 3      2023-06-30  ...  0001984539-23-000001  021-486754
# 4            None  ...  0001983466-23-000001  021-486751
# ...           ...  ...                   ...                        ...
# 40934  2023-09-19  ...  0001994032-23-000002  021-492526
# 40935  2023-04-07  ...  0001972237-23-000003  021-479110
# 40936  2023-08-09  ...  0001986286-23-000002  021-489519
# 40937  2023-08-01  ...  0001988652-23-000002  021-488753
# 40938  2023-07-25  ...  0001988021-23-000001  021-488454
#
#        FILING_DATE SIC_CODE SCHEMAVERSION SUBMISSIONTYPE TESTORLIVE  \
# 0      13-JUL-2023     None         X0708              D       LIVE
# 1      13-JUL-2023     None         X0708              D       LIVE
# 2      13-JUL-2023     None         X0708              D       LIVE
# 3      13-JUL-2023     None         X0708              D       LIVE
# 4      13-JUL-2023     None         X0708              D       LIVE
# ...            ...      ...           ...            ...        ...
# 40934  20-SEP-2023     None         X0708              D       LIVE
# 40935  17-AUG-2023     None         X0708            D/A       LIVE
# 40936  11-AUG-2023     None         X0708              D       LIVE
# 40937  04-AUG-2023     None         X0708              D       LIVE
# 40938  01-AUG-2023     None         X0708              D       LIVE
#
#       OVER100PERSONSFLAG OVER100ISSUERFLAG normalized_date
# 0                    NaN               NaN      2023-07-13
# 1                    NaN               NaN      2023-07-13
# 2                    NaN               NaN      2023-07-13
# 3                    NaN               NaN      2023-07-13
# 4                    NaN               NaN      2023-07-13
# ...                  ...               ...             ...
# 40934                NaN               NaN      2023-09-20
# 40935                NaN               NaN      2023-08-17
# 40936                NaN               NaN      2023-08-11
# 40937                NaN               NaN      2023-08-04
# 40938                NaN               NaN      2023-08-01
#
# [40939 rows x 74 columns]

# %%
# Close the connection
vc_database.close()
